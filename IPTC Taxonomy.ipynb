# %% [markdown]
# # Run this notebook in a virtualenv
#
# ```
# virtualenv --no-site-packages _notebook
# pip install -r requirements.txt
# ./_notebook/bin/jupyter notebook
# ```

# %%
import sys
from rdflib import Graph
from rdflib.namespace import Namespace, RDF, XSD, SKOS, RDFS
from anytree import Node, RenderTree, ContRoundStyle
from anytree.exporter import DotExporter

from SPARQLWrapper import SPARQLWrapper, JSON

from pprint import pprint

# %%
num = 0

# %%
def buildIPTCTree(ref):
    iptc = Node("IPTC", wikidata=None, label='IPTC') 
    for top_ref in g.objects(ref, SKOS.hasTopConcept):
        wd = findWikiData(top_ref)
        
        top = generateNode(top_ref, iptc)
        for sub_ref in g.objects(top_ref, SKOS.narrower):
            sub = generateNode(sub_ref, top)
            for subsub_ref in g.objects(sub_ref, SKOS.narrower):
                if len(g.preferredLabel(subsub_ref)) > 0:
                    subsub = generateNode(subsub_ref, sub)
    sys.stdout.flush()
    print("")
    return iptc

def generateNode(ref, parent):
    global num
    num = num + 1
    sys.stdout.write("\r%s" % (num*'.'))
    wikidata = findWikiData(ref)
    node = Node(ref, label=unicode(g.preferredLabel(ref)[0][1]), wikidata=wikidata, parent=parent)
    return node

# %%
def findWikiData(ref):
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

    # get wikidata ref from URI
    iptc_code = ref.replace('http://cv.iptc.org/newscodes/', '')

    # ?item wdt:P5429 ?iptc .
    # FILTER (?iptc IN ("mediatopic/20000735", "productgenre/entertainment" ) )
    # WikiData Property
    sparql.setQuery("""
            SELECT ?item ?itemLabel
            WHERE
            {
               # ?item wdt:P5429 "%s" .
               SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }
            }
            """ % (iptc_code))
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    if results['results']['bindings']:
        return results['results']['bindings'][0]
    return None

# %%
g = Graph()
g.parse("http://cv.iptc.org/newscodes/mediatopic/?format=rdfxml&lang=de")
# Out:
# <Graph identifier=Nfa9268222c204faa893dee50e088c785 (<class 'rdflib.graph.Graph'>)>

# %%
# get top concepts with 2 levels down (3 levels total)
ref = next(g.subjects(RDF.type, SKOS.ConceptScheme))
iptc = buildIPTCTree(ref)
for pre, fill, node in RenderTree(iptc, style=ContRoundStyle()):
    wd = node.wikidata
    if wd:
        wd = wd['item']['value'].replace('http://www.wikidata.org/entity/', '')

    print("%s%s (%s)" % (pre, node.label, wd))
# Out:
# ...............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# IPTC (None)
# ├── Erziehung, Ausbildung (Q8434)
# │   ├── Religionserziehung (Q1412471)
# │   ├── Eltern (None)
# │   ├── Schule (Q3914)
# │   │   ├── Hochschule (Q136822)
# │   │   ├── Gymnasium (Q9826)
# │   │   ├── Haupt-und Realschule (Q149566)
# │   │   ├── Grundschule (Q9842)
# │   │   ├── Vorschule/Kindergarten (Q1076052)
# │   │   ╰── Weiterbildung (Q765192)
# │   ├── Lehren und Lernen (None)
# │   │   ├── Prüfung (None)
# │   │   ├── Schüler (Q48282)
# │   │   ├── Lehrplan (Q207137)
# │   │   ╰── Lehrender (Q37226)
# │   ╰── Erziehung (Q2305519)
# ├── Gesellschaft, Bevölkerung (Q8425)
# │   ├── Sozialfürsorge (Q180043)
# │   │   ├── Sozialer Dienst (Q12055245)
# │   │   ├── Langzeitpflege (Q6672123)
# │   │   ╰── Wohltätigkeit (Q456673)
# │   ├── Familie (None)
# │   │   ├── Partnerwahl (Q376596)
# │   │   ├── Eltern und Kind (Q5362237)
# │   │   ├── Adoption (Q180472)
# │   │   ├── Heirat (Q8445)
# │   │   ├── Familienplanung (None)
# │   │   ╰── Scheidung (Q93190)
# │   ├── Soziale Bedingung (None)
# │   │   ├── Armut (Q10294)
# │   │   ╰── Obdachlosigkeit (Q131327)
# │   ├── Wertvorstellung (None)
# │   │   ├── Tod und Sterben (None)
# │   │   ├── SexuellesVerhalten (None)
# │   │   ├── Ethik (Q9465)
# │   │   ├── Korruptes Verhalten (Q5173053)
# │   │   ╰── Pornografie (Q291)
# │   ├── Bevölkerungsentwicklung (Q2725376)
# │   │   ├── Bevölkerungszahl (None)
# │   │   ╰── Einwanderung (Q131288)
# │   ├── Gesellschaft (Q177634)
# │   │   ╰── Soziales Netzwerk (None)
# │   ├── Soziales Problem (Q1920219)
# │   │   ├── Sucht (Q12029)
# │   │   ├── Prostitution (Q36633)
# │   │   ├── Sklaverei (Q8463)
# │   │   ├── Jugendkriminalität (Q1001125)
# │   │   ╰── Misshandlung (None)
# │   ├── Diskriminierung (Q169207)
# │   │   ├── Sexismus (Q93200)
# │   │   ├── Rassismus (Q8461)
# │   │   ├── Altersdiskriminierung (Q438946)
# │   │   ╰── Religiöse Diskriminierung (Q2029282)
# │   ╰── Bevölkerung (None)
# │       ├── Geschlecht (Q48277)
# │       ├── Senior (Q1358789)
# │       ├── Homosexuelle (None)
# │       ├── Behinderter (None)
# │       ├── Erwachsener (Q9584157)
# │       ├── Jugendlicher (Q1492760)
# │       ├── Kleinkind (None)
# │       ├── Strahlenopfer (None)
# │       ├── Kind (Q7569)
# │       ╰── Nationale oder ethische Minderheit (None)
# ├── Justiz, Kriminalität (None)
# │   ├── Gesetz (Q7748)
# │   │   ├── Bürgerliches Gesetzbuch (Q222249)
# │   │   ├── Strafgesetzbuch (Q146491)
# │   │   ╰── Internationales Recht (Q4394526)
# │   ├── Rechtsprechung (None)
# │   │   ╰── Zivilrecht (Q191600)
# │   ├── Kriminalität (Q83267)
# │   │   ├── Gewalt (Q365680)
# │   │   ├── Firmenkriminalität (Q5172452)
# │   │   ├── Kriegsverbrechen (Q135010)
# │   │   ├── Geiselnahme (Q318296)
# │   │   ├── Entführung (Q1933595)
# │   │   ├── Organisierte Kriminalität (Q46952)
# │   │   ├── Korruption (Q366)
# │   │   ├── Brandstiftung (Q327541)
# │   │   ├── Computerkriminalität (Q29137)
# │   │   ├── Diebstahl (Q2727213)
# │   │   ├── Drogenkriminalität (Q1259975)
# │   │   ├── Mord (Q149086)
# │   │   ├── Betrug (Q28813)
# │   │   ╰── Terrorismus (Q7283)
# │   ├── Sicherheitskräfte (BGS, LKA, BKA) (Q44554)
# │   │   ├── Untersuchungshaft (Q1403016)
# │   │   ├── Polizei (Q35535)
# │   │   ├── Strafanzeige (Q1964968)
# │   │   ╰── Strafe (Q12617289)
# │   ╰── Justiz (Q105985)
# │       ├── Anklage (Q6559173)
# │       ├── Außergerichtliche Einigung (None)
# │       ╰── Gericht (Q41487)
# ├── Kultur, Kunst, Unterhaltung und Medien (None)
# │   ├── Kultur (Q11042)
# │   │   ├── Brauchtum (Q251777)
# │   │   ├── Kulturgeschichte (None)
# │   │   ├── Bibliothek und Museum (None)
# │   │   ├── Sprache (Q315)
# │   │   ├── Fest (Kultur) (None)
# │   │   ╰── Denkmal und Gedenkstätte (None)
# │   ├── Massenmedien (Q11033)
# │   │   ├── Radio (Q273623)
# │   │   ├── Fernsehen (Q289)
# │   │   ├── Online Medien (None)
# │   │   ├── Nachrichtensender (Q1193236)
# │   │   ├── Zeitschrift (Q1002697)
# │   │   ├── Zeitung (Q11032)
# │   │   ╰── Soziale Medien (Q202833)
# │   ╰── Kunst und Unterhaltung (Q2018526)
# │       ├── Tanz (Q11639)
# │       ├── Festival (Q132241)
# │       ├── Kunstausstellung (Q667276)
# │       ├── Musik (Q638)
# │       ├── Film (Q16144339)
# │       ├── Literatur (Q8242)
# │       ├── Serie (Q20937557)
# │       ├── Mode (Q12684)
# │       ├── Animation (Q11425)
# │       ├── Comic (Q627603)
# │       ├── Theater (Q11635)
# │       ╰── Bildende Kunst (Q36649)
# ├── Arbeit, Soziales (Q6958747)
# │   ├── Arbeitsmarkt (Q305186)
# │   ├── Gewerkschaft (Q178790)
# │   ├── Arbeitsrecht (None)
# │   │   ╰── Arbeitssicherheit (None)
# │   ├── Ruhestand (Q946865)
# │   │   ╰── Rente (Q156223)
# │   ├── Arbeitslosigkeit (Q41171)
# │   │   ├── Personalabbau (None)
# │   │   ╰── Arbeitslosengeld (Q311255)
# │   ├── Arbeitsbeziehung (Q608190)
# │   │   ├── Tarifvertrag (None)
# │   │   ╰── Tarifkonflikt (None)
# │   ╰── Beschäftigung (Q656365)
# │       ├── Lohn (None)
# │       ├── Berufliche Bildung (None)
# │       ├── Beruf (Q12737077)
# │       ├── Kinderarbeit (Q192571)
# │       ├── Arbeitnehmer (Q703534)
# │       ├── Arbeitgeber (Q3053337)
# │       ├── Ausbildung (Q253567)
# │       ╰── Pendelverkehr (Q48442)
# ├── Katastrophe und Unglück (None)
# │   ├── Katastrophe (Q3839081)
# │   │   ├── Hunger (Q168247)
# │   │   ├── Naturkatastrophe (Q8065)
# │   │   ╰── Feuer (Q3196)
# │   ├── Unglück (None)
# │   │   ├── Transportunglück (None)
# │   │   ├── Explosion (None)
# │   │   ├── Konstruktionsfehler (Q1309431)
# │   │   ╰── Industrieunglück (None)
# │   ├── Notfall (Q5070802)
# │   │   ╰── Transportnotfall (Q11822042)
# │   ├── Hilfsorganisation (Q55692637)
# │   ╰── Katastrophenschutz (None)
# ├── Krise, Krieg, Konflikte (None)
# │   ├── Terroranschlag (Q5710433)
# │   │   ├── Bioterrorismus (None)
# │   │   ╰── Bombenattentat (None)
# │   ├── Wiederaufbau (Q3422086)
# │   │   ├── Abrüstung (Q331662)
# │   │   ╰── Kampfmittelbeseitigung (None)
# │   ├── Bewaffneter Konflikt (Q350604)
# │   │   ├── Internationale militärische Intervention (None)
# │   │   ├── Krieg (Q198)
# │   │   ├── Guerilla (None)
# │   │   ├── Kriegsvermisste (None)
# │   │   ╰── Militärische Besetzung (Q188686)
# │   ├── Unruhen (Q686984)
# │   │   ├── Rebellion (Q124734)
# │   │   ├── Revolution (Q10931)
# │   │   ├── Ausschreitung (Q124757)
# │   │   ╰── Demonstration (None)
# │   ├── Kriegsgefangene (None)
# │   ├── Friedensprozess (None)
# │   │   ├── Friedensplan (None)
# │   │   ├── Friedensverhandlung (None)
# │   │   ╰── Friedensgespräche (None)
# │   ├── Massaker (Q3199915)
# │   │   ╰── Völkermord (Q41397)
# │   ╰── Staatsstreich (Q45382)
# ├── Politik (Q7163)
# │   ├── Krise (Q3002772)
# │   ├── Regierungsunabhängige Organisation (Q79913)
# │   ├── Regierung (Q7188)
# │   │   ├── Bundesregierung (Q1320217)
# │   │   ├── Verteidigung (Q17991228)
# │   │   ├── Spionage und Geheimdienst (None)
# │   │   ├── Staatshaushalt (Q271855)
# │   │   ├── Minister (None)
# │   │   ├── Staatsoberhaupt/Bundespräsident (Q48352)
# │   │   ├── Öffentlicher Dienst (None)
# │   │   ├── Ministerium (None)
# │   │   ├── Verfassung (Gesetz) (Q7755)
# │   │   ├── Amtsvergehen (Q480498)
# │   │   ├── Bundeskabinett (None)
# │   │   ├── Bundesland/Kanton (None)
# │   │   ├── Parlament (Q35749)
# │   │   ╰── Kommune (None)
# │   ├── Internationale Beziehung (Q166542)
# │   │   ├── Auslandshilfe (Q2827815)
# │   │   ├── Diplomatie (Q1889)
# │   │   ├── Internationale Organisation (Q484652)
# │   │   ├── Wirtschaftliche Sanktion (Q1248258)
# │   │   ╰── Flüchtling (None)
# │   ├── Wahl (Q40231)
# │   │   ├── Bundestagswahl (None)
# │   │   ├── Landtagswahl/Bürgerschaftswahl (None)
# │   │   ├── Wahlkampf (Q847301)
# │   │   ├── Vorwahl (Q669262)
# │   │   ├── Wahlsystem (None)
# │   │   ├── staatsübergreifende Wahl (None)
# │   │   ├── Bürgerinitiative (None)
# │   │   ├── Kommunalwahl (Q15966540)
# │   │   ├── Kandidat (Q19772737)
# │   │   ├── Referendum (Q43109)
# │   │   ╰── Stimmwahl (Q189760)
# │   ├── Grundrechte (Q3237872)
# │   │   ├── Menschenrechte (Q8458)
# │   │   ├── Pressefreiheit (Q22688)
# │   │   ├── Religionsfreiheit (Q171899)
# │   │   ├── Zivilrecht (Q191600)
# │   │   ╰── Zensur (Q543)
# │   ├── Regierungspolitik (Q546113)
# │   │   ├── Innere Sicherheit (None)
# │   │   ├── Regulierungsbehörde (None)
# │   │   ├── Innenpolitik (Q1573035)
# │   │   ├── Kulturpolitik (Q1711347)
# │   │   ├── Wirtschaftspolitik (None)
# │   │   ├── Migration (None)
# │   │   ├── Sportpolitik (None)
# │   │   ├── Atompolitik (Q757637)
# │   │   ╰── Steuern (Q8161)
# │   ├── Politik (allgemein) (None)
# │   │   ├── Lobby (Q187117)
# │   │   ├── Politikgeschichte (None)
# │   │   ├── Partei (Q7278)
# │   │   ╰── Politisches System (Q28108)
# │   ╰── Politische Unruhen (Q7210284)
# ├── Vermischtes (None)
# │   ├── Pflanze (Q756)
# │   ├── Tier (Q729)
# │   ├── Zeremonie (Q2627975)
# │   ├── Leute (Q2472587)
# │   │   ├── Society (Q17126676)
# │   │   ╰── Missgeschick (None)
# │   ╰── Erungenschaft (Q21013267)
# │       ├── Rekord (None)
# │       ╰── Auszeichnung und Preis (None)
# ├── Umwelt (Q2249676)
# │   ├── Klimaveränderung (Q125928)
# │   │   ╰── Klimaerwärmung (Q7942)
# │   ├── Naturschutz (Q628403)
# │   │   ├── Energiesparen (Q380170)
# │   │   ╰── Naturschutzgebiet (Q22698)
# │   ├── Umweltverschmutzung (None)
# │   │   ├── Umweltsäuberung (None)
# │   │   ├── Abfall (Q45701)
# │   │   ├── Wasserverschmutzung (Q183129)
# │   │   ├── Giftstoff (None)
# │   │   ╰── Luftverschmutzung (Q131123)
# │   ├── Ressourcen (Q188460)
# │   │   ├── Land (Q55725874)
# │   │   ├── Bevölkerungsentwicklung (Q386191)
# │   │   ├── Wasser (Q283)
# │   │   ├── Rohstoff (Q1522115)
# │   │   ╰── Erneuerbare Energien (Q12705)
# │   ├── Umweltpolitik (None)
# │   ╰── Natur (Q7860)
# │       ├── Invasive Arten (Q183368)
# │       ├── Ökosystem (Q37813)
# │       ╰── Artenschutz (Q11394)
# ├── Wirtschaft und Finanzen (None)
# │   ├── Branchen (Q3958441)
# │   │   ├── Computer und Informationstechnologie (None)
# │   │   ├── Bau (None)
# │   │   ├── Metall- und Technische Industrie  (None)
# │   │   ├── Energie (None)
# │   │   ├── Chemie (Q79529)
# │   │   ├── Verarbeitende Industrie (None)
# │   │   ├── Konsumgüter (None)
# │   │   ├── Agrar (Q11451)
# │   │   ├── Metall und Mineralien (None)
# │   │   ├── Tourismus und Freizeit (None)
# │   │   ├── Dienstleistung (None)
# │   │   ├── Medien (None)
# │   │   ╰── Transport (Q7590)
# │   ├── Wirtschaft (Q159810)
# │   │   ├── Wirtschaftspolitik (None)
# │   │   ╰── Volkswirtschaft (Q39680)
# │   ├── Markt und Börse (None)
# │   │   ├── Aktien (Q1196314)
# │   │   ├── Kreditmarkt (None)
# │   │   ├── Kapitalmarkt (None)
# │   │   ├── Warenbörse (Q2922469)
# │   │   ├── Devisenmarkt (Q66076)
# │   │   ╰── Börse (Q169489)
# │   ╰── Firmeninformation (Q1391314)
# │       ├── Marketing (None)
# │       ├── Unternehmenszahlen (None)
# │       ╰── Personal (Q1920785)
# ├── Freizeit, Modernes Leben (None)
# │   ├── Lebensstil (Q32090)
# │   │   ├── Auto (None)
# │   │   ├── Wohnungseinrichtung (None)
# │   │   ├── Fahrrad (None)
# │   │   ├── Essen und Trinken (None)
# │   │   ├── Motorrad (None)
# │   │   ├── Trend (None)
# │   │   ╰── Party (Q200538)
# │   ╰── Freizeit (Q180910)
# │       ├── Verein (None)
# │       ├── Glücksspiel und Lotterie (None)
# │       ├── Hobby (Q47728)
# │       ├── Spiel (Q11410)
# │       ├── Reise (Q61509)
# │       ├── Urlaub (None)
# │       ├── Freizeitaktivität (None)
# │       ╰── Veranstaltungsort (None)
# ├── Wissenschaft, Technik, Forschung (Q34104)
# │   ├── Mathematik (Q395)
# │   ├── Forschung (Q42240)
# │   │   ├── Wissenschaftliche Veröffentlichung (Q13442814)
# │   │   ├── Forschung und Entwicklung (None)
# │   │   ├── Wissenschaftliche Forschung (None)
# │   │   ╰── Medizinische Forschung (Q2752427)
# │   ├── Technologie und Technik (None)
# │   │   ├── Ingenieurwesen (Q77590)
# │   │   ├── Informatik (None)
# │   │   ├── Technologie zur Identitätsprüfung (None)
# │   │   ├── Mikroelektronik (None)
# │   │   ├── Eletrotechnik (Q11650)
# │   │   ├── Agrarwissenschaft (None)
# │   │   ├── Luft- und Raumfahrttechnik (Q3798668)
# │   │   ╰── Materialwissenschaft (Q228736)
# │   ├── Wissenschaftliche Institutionen (None)
# │   ├── Sozialwissenschaften (Q34749)
# │   │   ├── Jura (Q4932206)
# │   │   ├── Informationswissenschaft (Q16387)
# │   │   ├── Wirtschaftswissenschaft (Q8134)
# │   │   ├── Geschichte (Q1066186)
# │   │   ├── Psychologie (Q9418)
# │   │   ├── Philosophie (Q5891)
# │   │   ├── Anthropologie (Q23404)
# │   │   ├── Politikwissenschaft (Q36442)
# │   │   ├── Soziologie (Q21201)
# │   │   ├── Archäologie (Q23498)
# │   │   ├── Geografie (Q1071)
# │   │   ╰── Linguistik (Q8162)
# │   ├── Standards (None)
# │   ├── Biomedizin (Q16745563)
# │   │   ├── Zahnmedizin (Q12128)
# │   │   ├── Pharmakologie (Q128406)
# │   │   ├── Biotechnologie (None)
# │   │   ╰── Tiermedizin (None)
# │   ├── Naturwissenschaft (Q7991)
# │   │   ├── Astronomie (Q333)
# │   │   ├── Meteorologie (Q25261)
# │   │   ├── Chemie (Q2329)
# │   │   ├── Physik (Q413)
# │   │   ├── Gartenbau (Q48803)
# │   │   ├── Geologie (Q1069)
# │   │   ├── Biologie (Q420)
# │   │   ├── Meeresforschung (Q24577909)
# │   │   ╰── Kosmologie (Q338)
# │   ╰── Maschinenbau (Q101333)
# ├── Wetter (None)
# │   ├── Wetterphänomene (None)
# │   ├── Unwetterwarnung (Q7978253)
# │   ├── Wetterstatistik (None)
# │   ╰── Vorhersage (Q182868)
# ├── Religion, Weltanschauung (None)
# │   ├── Glaube (Q2728698)
# │   │   ├── Freimaurer (Q41726)
# │   │   ├── Jainismus (Q9232)
# │   │   ├── Islam (Q432)
# │   │   ├── Schintoismus (Q812767)
# │   │   ├── Naturreligion (Q12291451)
# │   │   ├── Christentum (Q5043)
# │   │   ├── Konfuzianismus (Q9581)
# │   │   ├── Vereinigungsbewegung (None)
# │   │   ├── Scientology (Q131036)
# │   │   ├── Kult und Sekte (None)
# │   │   ├── Taoismus (Q9598)
# │   │   ├── Sikhismus (Q9316)
# │   │   ├── Judentum (Q9268)
# │   │   ├── Hinduismus (Q9089)
# │   │   ├── Zoroastrismus (None)
# │   │   ╰── Buddhismus (Q748)
# │   ├── Beziehung Religion und Staat (None)
# │   ├── Religiöses Ereignis (None)
# │   │   ├── Religionsfest oder Feiertag (None)
# │   │   ╰── Religionsritual (None)
# │   ├── Interreligiöser Dialog (None)
# │   ├── Religiöse Bauwerke (None)
# │   │   ├── Moschee (Q32815)
# │   │   ├── Synagoge (Q34627)
# │   │   ├── Kirche (Q16970)
# │   │   ╰── Tempel (Q44539)
# │   ├── Religionskonfliktl (Q7311342)
# │   ├── Religiöses Oberhaupt (Q15995642)
# │   │   ╰── Papst (Q19546)
# │   ╰── Religiöse Schriften (Q179461)
# │       ├── Koran (Q428)
# │       ├── Thora (Q34990)
# │       ╰── Bibel (Q1845)
# ├── Sport (Q349)
# │   ├── Disziplin (Q2312410)
# │   │   ├── Tauziehen (Q102843)
# │   │   ├── Bob (Q177275)
# │   │   ├── Lacrosse (Q185851)
# │   │   ├── Inline Skating (Q6034982)
# │   │   ├── Moderner Fünfkampf (Q32485)
# │   │   ├── Canadian Football (Q248534)
# │   │   ├── Eisschnelllauf (Q192431)
# │   │   ├── Bergsteigen (None)
# │   │   ├── Gaelic football (Q204632)
# │   │   ├── Shorttrack Eisschnellauf (Q193654)
# │   │   ├── Pferderennen (Q187916)
# │   │   ├── Billiard (Q11020)
# │   │   ├── Radsport (None)
# │   │   ├── Schießen (None)
# │   │   ├── Skeleton (Q186190)
# │   │   ├── Schwimmen (Q31920)
# │   │   ├── Rodeo (Q207703)
# │   │   ├── Wasserski (None)
# │   │   ├── Sky Diving (None)
# │   │   ├── Unihockey (Q206763)
# │   │   ├── Snowboard (Q178131)
# │   │   ├── Wasserball (Q7707)
# │   │   ├── Ski (Q130949)
# │   │   ├── Billard (None)
# │   │   ├── Biathlon (Q166788)
# │   │   ├── Gewichtheben (Q83462)
# │   │   ├── Crocket (Q193387)
# │   │   ├── Motorboot (None)
# │   │   ├── Triathlon (Q10980)
# │   │   ├── Wellenreiten (Q159992)
# │   │   ├── Tennis (Q847)
# │   │   ├── Casting (Angeln) (None)
# │   │   ├── Bowling (Q172809)
# │   │   ├── Turnen (Q43450)
# │   │   ├── Hunderennen (None)
# │   │   ├── Rudern (Q159354)
# │   │   ├── Rodeln (None)
# │   │   ├── Sepak Takraw (Q188818)
# │   │   ├── Kajak (None)
# │   │   ├── Hornussen (None)
# │   │   ├── Polo (Q134211)
# │   │   ├── Stierkampf (Q184940)
# │   │   ├── Eiskunstlauf (Q38108)
# │   │   ├── Jai Alai (Pelota) (Q1193361)
# │   │   ├── Motorsport (None)
# │   │   ├── Australian rules football (Q50776)
# │   │   ├── Kanu (None)
# │   │   ├── Netzball (Q231200)
# │   │   ├── Frisbee (Q131689)
# │   │   ├── Feldhockey (Q1455)
# │   │   ├── Segeln (Q14085739)
# │   │   ├── Tanzen (Q1415387)
# │   │   ├── Motorradrennen (Q608003)
# │   │   ├── Boxen (Q32112)
# │   │   ├── Leichtathletik (None)
# │   │   ├── Turm- und Brettspringen (Q7735)
# │   │   ├── Tischtennis (Q3930)
# │   │   ├── Duathlon (Q429006)
# │   │   ├── Ringen (Q42486)
# │   │   ├── Fechten (Q12100)
# │   │   ├── Volleyball (Q1734)
# │   │   ├── Bogenschießen (Q108429)
# │   │   ├── Motorbootsport (None)
# │   │   ├── Boules und Pètanque (None)
# │   │   ├── Sumo (None)
# │   │   ├── Squash (Q133201)
# │   │   ├── Windsurfen (Q191051)
# │   │   ├── Kabaddi (Q148636)
# │   │   ├── Baseball (Q5369)
# │   │   ├── Hurling (Q213711)
# │   │   ├── Eishockey (Q41466)
# │   │   ├── Fallschirmspringen (None)
# │   │   ├── Handball (Team) (Q8418)
# │   │   ├── Curling (Q136851)
# │   │   ├── Fußball (None)
# │   │   ├── Faustball (None)
# │   │   ├── Orientierung (Q29358)
# │   │   ├── Kricket (Q5375)
# │   │   ├── Snooker (Q11015)
# │   │   ├── Softball (Q171038)
# │   │   ├── Shinty (Q850256)
# │   │   ├── Basketball (Q5372)
# │   │   ├── Pferdesport (Q179226)
# │   │   ├── Golf (Q5377)
# │   │   ├── Dart (Q131471)
# │   │   ├── Badminton (Q7291)
# │   │   ├── Bandy (Q183018)
# │   │   ├── American football (Q41323)
# │   │   ╰── Marathon (Q40244)
# │   ├── Sportstätte (Q1076486)
# │   ├── Doping (allgemein) (None)
# │   │   ├── Drogentest (None)
# │   │   ├── Medizinisches Doping (None)
# │   │   ╰── Doping (None)
# │   ├── Sportindustrie (Q8797432)
# │   ├── Sportorganisation (Q4438121)
# │   ├── Sportereignis (Q167170)
# │   │   ├── Kontinentaler Cup (None)
# │   │   ├── Regionale Meisterschaft (None)
# │   │   ├── Weltmeisterschaft (Q1344963)
# │   │   ├── Nationale Meisterschaft (Q3270632)
# │   │   ├── Regionale Spiele (None)
# │   │   ├── Kontinentale Spiele (None)
# │   │   ├── Internationale Meisterschaft (None)
# │   │   ├── Nationaler Cup (None)
# │   │   ├── Regionaler Cup (None)
# │   │   ├── Weltcup (Q1936368)
# │   │   ├── Kontinentale Meisterschaft (None)
# │   │   ├── Weltspiele (None)
# │   │   ├── Nationale Spiele (None)
# │   │   ├── Internationale Spiele (None)
# │   │   ╰── Internationaler Cup (None)
# │   ├── Disziplinarmaßnahmen im Sport (None)
# │   ╰── Transfer (Q56072650)
# ╰── Medizin, Gesundheit (Q12147)
#     ├── Gesundheitseinrichtung (Q4260475)
#     │   ╰── Krankenhaus (None)
#     ├── Medizinische Behandlung (None)
#     │   ├── Medizinische Untersuchung (None)
#     │   ├── Fitness (Q309252)
#     │   ├── Vorsorge (Q1773974)
#     │   ├── Therapie (Q179661)
#     │   ├── Medikament (Q12140)
#     │   ├── Diät (Q26869695)
#     │   ╰── Medizinische Droge (None)
#     ├── Gesundheitsorganisation (Q5691113)
#     ├── Krankheit (Q12136)
#     │   ├── Krankheitsverlauf (None)
#     │   ├── Herzkrankheit (Q190805)
#     │   ├── Übergewicht (Q12174)
#     │   ├── Invalidität (Q193078)
#     │   ├── Ansteckende Krankheit (None)
#     │   ├── Krebs (Q12078)
#     │   ├── Psychische Krankheit (Q30085742)
#     │   ╰── Leiden (Q814207)
#     ├── Nicht-menschliche Krankheit (None)
#     │   ├── Pflanzenkrankheit (Q2662845)
#     │   ╰── Tierkrankheit (Q9190427)
#     ├── Gesundheitspolitik (None)
#     │   ├── Gesetzliche Krankenversicherung (None)
#     │   ├── Private Krankenversicherung (Q615678)
#     │   ╰── Zusatzversicherung (Q334911)
#     ╰── Medizin (None)
#         ├── Medizinischer Service (Q55698119)
#         ├── Gesundheitspersonal (None)
#         ╰── Medizinisches Spezialgebiet (None)
